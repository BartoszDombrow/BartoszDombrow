# %% [markdown]
# <a href="https://colab.research.google.com/github/BartoszDombrow/BartoszDombrow/blob/main/stata_19_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = "http://theta.edu.pl/wp-content/uploads/2023/10/Dane.csv"
dane = pd.read_csv(url)
df.head()
# Out:
#         Start        Stop  SEX  height  weight  NTproBNP  Hemoglobina  \
# 0  2008-12-23  2011-07-01    1     177     100  4.127134    12.246213
# 1  2008-12-23  2011-07-01    0     170      84  5.351858    12.890751
# 2  2008-12-19  2011-07-01    0     179      76  4.276666    14.340960
# 3  2008-12-19  2011-07-01    1     186     121  5.036953    14.502095
# 4  2008-12-18  2011-07-01    1     157      56  5.726848    16.274573
#
#        sTfR  zgon
# 0  0.756122     1
# 1  0.966984     1
# 2  0.703098     0
# 3  0.883768     1
# 4  0.858662     1

# %%
# !pip install lifelines
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.3/349.3 kB 11.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.7/115.7 kB 9.6 MB/s eta 0:00:00
# ...
#   Created wheel for autograd-gamma: filename=autograd_gamma-0.5.0-py3-none-any.whl size=4030 sha256=8100555b9f5efe0546c3461ba59ddb9ea326179fb01d6510c88087b1b4639944
#   Stored in directory: /root/.cache/pip/wheels/8b/67/f4/2caaae2146198dcb824f31a303833b07b14a5ec863fb3acd7b
# Successfully built autograd-gamma
# ...

# %%
from lifelines import WeibullFitter, ExponentialFitter, KaplanMeierFitter
from lifelines.utils import datetimes_to_durations
import matplotlib.pyplot as plt

# %%
dane['duration'] = datetimes_to_durations(dane['Start'], dane['Stop'])[0]

# %%
weibull_model = WeibullFitter()
weibull_model.fit(dane['duration'], event_observed = dane['zgon'])
# Out:
# <lifelines.WeibullFitter:"Weibull_estimate", fitted with 87 total observations, 38 right-censored observations>

# %%
weibull_model.summary
# Out:
#                 coef   se(coef)  coef lower 95%  coef upper 95%  cmp to  \
# lambda_  1224.351928  20.772623     1183.638335     1265.065522     1.0
# rho_        8.468724   0.935764        6.634659       10.302788     1.0
#
#                  z             p   -log2(p)
# lambda_  58.892511  0.000000e+00        inf
# rho_      7.981414  1.446659e-15  49.296197

# %%
weibull_model.hazard_
# Out:
#              Weibull_estimate
# 920.000000           0.000818
# 924.686047           0.000850
# 929.372093           0.000883
# 934.058140           0.000916
# 938.744186           0.000951
# ...                       ...
# 1304.255814          0.011091
# 1308.941860          0.011392
# 1313.627907          0.011700
# 1318.313953          0.012016
# 1323.000000          0.012338
#
# [87 rows x 1 columns]

# %%
weibull_model.survival_function_
# Out:
#              Weibull_estimate
# 920.000000           0.914942
# 924.686047           0.911373
# 929.372093           0.907681
# 934.058140           0.903864
# 938.744186           0.899917
# ...                       ...
# 1304.255814          0.181204
# 1308.941860          0.171906
# 1313.627907          0.162852
# 1318.313953          0.154050
# 1323.000000          0.145506
#
# [87 rows x 1 columns]

# %%
weibull_model.median_survival_time_
# Out:
# np.float64(1172.4941743385273)

# %%
weibull_model.AIC_
# Out:
# np.float64(687.8858271412171)

# %%
expo_model = ExponentialFitter()
expo_model.fit(dane['duration'], event_observed = dane['zgon'])
# Out:
# <lifelines.ExponentialFitter:"Exponential_estimate", fitted with 87 total observations, 38 right-censored observations>

# %%
expo_model.summary
# Out:
#                coef    se(coef)  coef lower 95%  coef upper 95%  cmp to    z  \
# lambda_  1928.71426  275.530605     1388.684198     2468.744322     0.0  7.0
#
#                     p   -log2(p)
# lambda_  2.559623e-12  38.507206

# %%
expo_model.hazard_
# Out:
#              Exponential_estimate
# 920.000000               0.000518
# 924.686047               0.000518
# 929.372093               0.000518
# 934.058140               0.000518
# 938.744186               0.000518
# ...                           ...
# 1304.255814              0.000518
# 1308.941860              0.000518
# 1313.627907              0.000518
# 1318.313953              0.000518
# 1323.000000              0.000518
#
# [87 rows x 1 columns]

# %%
expo_model.survival_function_
# Out:
#              Exponential_estimate
# 920.000000               0.620641
# 924.686047               0.619135
# 929.372093               0.617633
# 934.058140               0.616134
# 938.744186               0.614639
# ...                           ...
# 1304.255814              0.508530
# 1308.941860              0.507296
# 1313.627907              0.506065
# 1318.313953              0.504837
# 1323.000000              0.503612
#
# [87 rows x 1 columns]

# %%
print(round (expo_model.median_survival_time_, 2))
# Out:
# 1336.88

# %%
print(round (expo_model.AIC_, 2))
# Out:
# 841.33

# %%
kaplan_model = KaplanMeierFitter()
kaplan_model.fit(dane['duration'], event_observed = dane['zgon'])
# Out:
# <lifelines.KaplanMeierFitter:"KM_estimate", fitted with 87 total observations, 38 right-censored observations>

# %%
kaplan_model.median_survival_time_
# Out:
# np.float64(1176.0)

# %%
kaplan_model.survival_function_
# Out:
#           KM_estimate
# timeline
# 0.0          1.000000
# 920.0        0.977011
# 924.0        0.965517
# 925.0        0.942252
# 931.0        0.942252
# 932.0        0.942252
# 938.0        0.930015
# 939.0        0.905541
# 941.0        0.905541
# 946.0        0.892964
# 952.0        0.892964
# 959.0        0.880022
# 960.0        0.854139
# 966.0        0.828256
# 973.0        0.828256
# 974.0        0.828256
# 980.0        0.828256
# 981.0        0.787522
# 994.0        0.787522
# 1002.0       0.787522
# 1003.0       0.773459
# 1008.0       0.759136
# 1009.0       0.730489
# 1015.0       0.701843
# 1016.0       0.687519
# 1030.0       0.687519
# 1036.0       0.657627
# 1043.0       0.657627
# 1068.0       0.657627
# 1078.0       0.641970
# 1079.0       0.641970
# 1099.0       0.609871
# 1100.0       0.609871
# 1113.0       0.592930
# 1114.0       0.575989
# 1120.0       0.575989
# 1131.0       0.558535
# 1134.0       0.541081
# 1142.0       0.523045
# 1162.0       0.523045
# ...

# %%
plt.figure(figsize=(10,6))
kaplan_model.plot_survival_function(label="KA")
